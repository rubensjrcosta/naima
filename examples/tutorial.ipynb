# %%
from naima.models import ExponentialCutoffPowerLaw, InverseCompton
import astropy.units as u
import numpy as np


def model_function(pars, data):
    amplitude = pars[0] * (1 / u.eV)
    alpha = pars[1]
    e_cutoff = (10 ** pars[2]) * u.TeV
    e_0 = 10 * u.TeV

    ECPL = ExponentialCutoffPowerLaw(amplitude, e_0, alpha, e_cutoff)
    IC = InverseCompton(
        ECPL,
        seed_photon_fields=[
            "CMB",
            ["FIR", 26.5 * u.K, 0.415 * u.eV / u.cm ** 3],
        ],
    )

    # The total enegy in electrons of model IC can be accessed through the
    # attribute We or obtained for a given range with compute_We
    We = IC.compute_We(Eemin=1 * u.TeV)

    # We can also save the particle distribution between 100 MeV and 100 TeV
    electron_e = np.logspace(11, 15, 100) * u.eV
    electron_dist = ECPL(electron_e)

    # The first object returned must be the model photon spectrum, and
    # subsequent objects will be stored as metadata blobs
    return IC(data), (electron_e, electron_dist), We

# %% [markdown]
# ## Tutorial

# %% [markdown]
# The first step in fitting a model to an observed spectrum is to read the spectrum into the appropriate format. See Data format for an explanation of the format and an example, and Units system for a brief explanation of the unit system used in Naima. We load the spectral data with astropy.io.ascii:

# %%
from astropy.io import ascii

data = ascii.read("RXJ1713_HESS_2007.dat")
data
# Out:
# <Table length=28>
#  energy energy_edge_lo energy_edge_hi       flux         flux_error     ul
#   TeV        TeV            TeV       1 / (cm2 s TeV) 1 / (cm2 s TeV)
# float64    float64        float64         float64         float64     int64
# ------- -------------- -------------- --------------- --------------- -----
#    0.33            0.3           0.37        2.29e-10         3.2e-11     0
#     0.4           0.37           0.44        1.25e-10         1.6e-11     0
#    0.49           0.44           0.54        9.46e-11           9e-12     0
#    0.59           0.54           0.65        6.06e-11         5.2e-12     0
#    0.71           0.65           0.79        4.37e-11         3.1e-12     0
#    0.86           0.79           0.95        2.15e-11         1.8e-12     0
#     ...            ...            ...             ...             ...   ...
#   22.18          20.24           24.5        9.24e-15        3.16e-15     0
#   26.85           24.5          29.66         7.4e-15        2.06e-15     0
#    32.5          29.66          35.91        6.46e-15         1.5e-15     0
#   47.19          35.91          63.71        9.63e-16        3.93e-16     0
#   81.26          63.71         113.02        1.98e-16        1.29e-16     0
#  169.79         113.02         293.82        1.35e-16             0.0     1

# %%
from naima.models import ExponentialCutoffPowerLaw, InverseCompton
import astropy.units as u


def model(pars, data):
    amplitude = pars[0] / u.eV
    alpha = pars[1]
    e_cutoff = (10 ** pars[2]) * u.TeV

    ECPL = ExponentialCutoffPowerLaw(amplitude, 10 * u.TeV, alpha, e_cutoff)
    IC = InverseCompton(
        ECPL,
        seed_photon_fields=[
            "CMB",
            ["FIR", 26.5 * u.K, 0.415 * u.eV / u.cm ** 3],
        ],
    )

    return IC.flux(data, distance=1.0 * u.kpc)

# %%
import naima

# %%
from naima import uniform_prior

def lnprior(pars):
    lnprior = uniform_prior(pars[0], 0.0, np.inf) + uniform_prior(pars[1], -1, 5)
    return lnprior

# %%
import numpy as np
p0 = np.array((1e33, 3.0, np.log10(30)))
labels = ["norm", "index", "log10(cutoff)"]

# %%
imf = naima.InteractiveModelFitter(model, p0, data=data, labels=labels)
# interactive fitting done
p0 = imf.pars

# %%
naima.get_sampler()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 naima.get_sampler()
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/site-packages/naima/core.py:352, in get_sampler(data_table, p0, model, prior, nwalkers, nburn, guess, interactive, prefit, labels, threads, data_sed)
#     249 """Generate a new MCMC sampler.
#     250
#     251 Parameters
#    (...)
#     349 emcee.EnsembleSampler
#     350 """
#     351 if data_table is None:
# --> 352     raise TypeError("Data table is missing!")
#     353 else:
#     354     data = validate_data_table(data_table, sed=data_sed)
#
# TypeError: Data table is missing!

# %%
import naima

sampler, pos = naima.run_sampler(
    data_table=data,
    p0=p0,
    labels=labels,
    model=model,
    prior=lnprior,
    nwalkers=128,
    nburn=50,
    nrun=10,
    threads=4,
     interactive=True,
)
# Out:
# INFO: Launching interactive model fitter, close when finished [naima.core]
# WARNING: "cl" keyword not provided in input data table, upper limits will be assumed to be at 90% confidence level [naima.utils]
# Burning in the 128 walkers with 50 steps...
#
# Progress of the run: 0 percent (0 of 50 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.86e+32          2.92            1.47
#   Last ensemble std    :    1.74e+31          0.281           0.152
#   Last ensemble lnprob :  avg: -240.919, max: -29.693
#
# Progress of the run: 10 percent (5 of 50 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.81e+32          2.83            1.49
#   Last ensemble std    :     2.1e+31          0.258           0.15
#   Last ensemble lnprob :  avg: -143.037, max: -19.060
#
# Progress of the run: 20 percent (10 of 50 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.75e+32          2.75            1.51
#   Last ensemble std    :    2.21e+31          0.271           0.14
#   Last ensemble lnprob :  avg: -93.722, max: -19.009
#
# Progress of the run: 30 percent (15 of 50 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.69e+32          2.66            1.51
#   Last ensemble std    :    2.11e+31          0.226           0.124
#   Last ensemble lnprob :  avg: -62.991, max: -19.015
#
# Progress of the run: 40 percent (20 of 50 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.64e+32          2.61            1.53
#   Last ensemble std    :    2.27e+31          0.191           0.131
#   Last ensemble lnprob :  avg: -42.098, max: -18.150
#
# Progress of the run: 50 percent (25 of 50 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.61e+32          2.56            1.53
#   Last ensemble std    :    2.28e+31          0.187           0.139
#   Last ensemble lnprob :  avg: -33.907, max: -18.197
#
# Progress of the run: 60 percent (30 of 50 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.56e+32          2.52            1.56
#   Last ensemble std    :    2.09e+31          0.153           0.135
#   Last ensemble lnprob :  avg: -26.153, max: -18.120
#
# Progress of the run: 70 percent (35 of 50 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.53e+32          2.52            1.58
#   Last ensemble std    :    2.09e+31          0.151           0.134
#   Last ensemble lnprob :  avg: -22.925, max: -18.044
#
# Progress of the run: 80 percent (40 of 50 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :     1.5e+32          2.52            1.59
#   Last ensemble std    :    2.08e+31          0.145           0.138
#   Last ensemble lnprob :  avg: -21.642, max: -18.139
#
# Progress of the run: 90 percent (45 of 50 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.47e+32          2.53            1.61
#   Last ensemble std    :    1.95e+31          0.143           0.129
#   Last ensemble lnprob :  avg: -20.968, max: -18.069
#
# Walker burn in finished, running 10 steps...
#
# Progress of the run: 0 percent (0 of 10 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.44e+32          2.54            1.64
#   Last ensemble std    :    1.95e+31          0.143           0.128
#   Last ensemble lnprob :  avg: -20.525, max: -18.021
#
# Progress of the run: 10 percent (1 of 10 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.44e+32          2.53            1.64
#   Last ensemble std    :    1.91e+31          0.14            0.126
#   Last ensemble lnprob :  avg: -20.404, max: -18.004
#
# Progress of the run: 20 percent (2 of 10 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.44e+32          2.53            1.64
#   Last ensemble std    :    1.88e+31          0.141           0.124
#   Last ensemble lnprob :  avg: -20.402, max: -18.039
#
# Progress of the run: 30 percent (3 of 10 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.44e+32          2.53            1.63
#   Last ensemble std    :    1.81e+31          0.14            0.124
#   Last ensemble lnprob :  avg: -20.259, max: -18.039
#
# Progress of the run: 40 percent (4 of 10 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.43e+32          2.53            1.63
#   Last ensemble std    :    1.82e+31          0.141           0.126
#   Last ensemble lnprob :  avg: -20.208, max: -18.010
#
# Progress of the run: 50 percent (5 of 10 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.44e+32          2.53            1.63
#   Last ensemble std    :    1.81e+31          0.139           0.125
#   Last ensemble lnprob :  avg: -20.287, max: -17.995
#
# Progress of the run: 60 percent (6 of 10 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.44e+32          2.53            1.63
#   Last ensemble std    :    1.85e+31          0.144           0.129
#   Last ensemble lnprob :  avg: -20.179, max: -18.042
#
# Progress of the run: 70 percent (7 of 10 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.44e+32          2.53            1.64
#   Last ensemble std    :    1.87e+31          0.147           0.13
#   Last ensemble lnprob :  avg: -20.201, max: -18.042
#
# Progress of the run: 80 percent (8 of 10 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.43e+32          2.53            1.64
#   Last ensemble std    :    1.89e+31          0.149           0.133
#   Last ensemble lnprob :  avg: -20.196, max: -18.085
#
# Progress of the run: 90 percent (9 of 10 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.43e+32          2.54            1.64
#   Last ensemble std    :    1.84e+31          0.14            0.129
#   Last ensemble lnprob :  avg: -20.109, max: -18.074

# %%
naima.save_diagnostic_plots(
    "RXJ1713_IC",
    sampler,
    blob_labels=[
        "Spectrum",
        "Electron energy distribution",
        "$W_e (E_e>1$ TeV)",
    ],
)

naima.save_results_table("RXJ1713_naima_fit", sampler)
# Out:
# INFO: Plotting chain of parameter norm... [naima.analysis]
# INFO: -----------------------norm-----------------------
#           norm = $(1.44 \pm 0.12)\times10^{32}$ [naima.plot]
# INFO: Plotting chain of parameter index... [naima.analysis]
# INFO: ----------------------index-----------------------
#           index = $2.53 \pm 0.13$ [naima.plot]
# INFO: Plotting chain of parameter log10(cutoff)... [naima.analysis]
# INFO: ------------------log10(cutoff)-------------------
#           log10(cutoff) = $1.63 \pm 0.12$
#                  cutoff = $43^{+13}_{-10}$ [naima.plot]
# INFO: Plotting corner plot... [naima.analysis]
# INFO: Plotting Spectrum... [naima.analysis]
# /home/born-again/anaconda3/envs/gammapy-1.0/lib/python3.9/site-packages/naima/analysis.py:163: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   f.clf()
# WARNING: plot_blob failed for Electron energy distribution: cannot convert float NaN to integer [naima.analysis]
# INFO: Plotting Electron energy distribution... [naima.analysis]
# INFO: Saving results table in RXJ1713_naima_fit_results.ecsv [naima.analysis]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [13], in <cell line: 11>()
#       1 naima.save_diagnostic_plots(
#       2     "RXJ1713_IC",
#       3     sampler,
#    (...)
#       8     ],
#       9 )
# ---> 11 naima.save_results_table("RXJ1713_naima_fit", sampler)
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/site-packages/naima/analysis.py:373, in save_results_table(outname, sampler, format, convert_log, last_step, include_blobs)
#     370     # Save it directly in meta for readability in ECSV
#     371     t.meta.update(metadata)
# --> 373 t.write("{0}_results.{1}".format(outname, file_extension), format=format)
#     375 return t
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/site-packages/astropy/table/connect.py:129, in TableWrite.__call__(self, serialize_method, *args, **kwargs)
#     127 instance = self._instance
#     128 with serialize_method_as(instance, serialize_method):
# --> 129     self.registry.write(instance, *args, **kwargs)
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/site-packages/astropy/io/registry/core.py:369, in UnifiedOutputRegistry.write(self, data, format, *args, **kwargs)
#     365     format = self._get_valid_format(
#     366         'write', data.__class__, path, fileobj, args, kwargs)
#     368 writer = self.get_writer(format, data.__class__)
# --> 369 return writer(data, *args, **kwargs)
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/site-packages/astropy/io/ascii/connect.py:26, in io_write(format, table, filename, **kwargs)
#      24     format = re.sub(r'^ascii\.', '', format)
#      25     kwargs['format'] = format
# ---> 26 return write(table, filename, **kwargs)
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/site-packages/astropy/io/ascii/ui.py:827, in write(table, output, format, Writer, fast_writer, overwrite, **kwargs)
#     825     output = os.path.expanduser(output)
#     826     if not overwrite and os.path.lexists(output):
# --> 827         raise OSError(NOT_OVERWRITING_MSG.format(output))
#     829 if output is None:
#     830     output = sys.stdout
#
# OSError: File RXJ1713_naima_fit_results.ecsv already exists. If you mean to replace it then use the argument "overwrite=True".
