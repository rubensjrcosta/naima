# %% [markdown]
# ## Fitting IC emission from an electron distribution

# %%
#!/usr/bin/env python
import astropy.units as u
import numpy as np
from astropy.io import ascii

import naima
from naima.models import ExponentialCutoffPowerLaw, InverseCompton

## Read data

data = ascii.read("RXJ1713_HESS_2007.dat")

## Model definition


def ElectronIC(pars, data):

    # Match parameters to ECPL properties, and give them the appropriate units
    amplitude = pars[0] / u.eV
    alpha = pars[1]
    e_cutoff = (10 ** pars[2]) * u.TeV

    # Initialize instances of the particle distribution and radiative model
    ECPL = ExponentialCutoffPowerLaw(amplitude, 10.0 * u.TeV, alpha, e_cutoff)
    # Compute IC on CMB and on a FIR component with values from GALPROP for the
    # position of RXJ1713
    IC = InverseCompton(
        ECPL,
        seed_photon_fields=[
            "CMB",
            ["FIR", 26.5 * u.K, 0.415 * u.eV / u.cm ** 3],
        ],
        Eemin=100 * u.GeV,
    )

    # compute flux at the energies given in data['energy'], and convert to units
    # of flux data
    model = IC.flux(data, distance=1.0 * u.kpc).to(data["flux"].unit)

    # Save this realization of the particle distribution function
    elec_energy = np.logspace(11, 15, 100) * u.eV
    nelec = ECPL(elec_energy)

    # Compute and save total energy in electrons above 1 TeV
    We = IC.compute_We(Eemin=1 * u.TeV)

    # The first array returned will be compared to the observed spectrum for
    # fitting. All subsequent objects will be stores in the sampler metadata
    # blobs.
    return model, (elec_energy, nelec), We


## Prior definition


def lnprior(pars):
    """
    Return probability of parameter values according to prior knowledge.
    Parameter limits should be done here through uniform prior ditributions
    """

    logprob = naima.uniform_prior(pars[0], 0.0, np.inf) + naima.uniform_prior(
        pars[1], -1, 5
    )

    return logprob


if __name__ == "__main__":

    ## Set initial parameters and labels
    p0 = np.array((1e30, 3.0, np.log10(30)))
    labels = ["norm", "index", "log10(cutoff)"]

    ## Run sampler
    sampler, pos = naima.run_sampler(
        data_table=data,
        p0=p0,
        labels=labels,
        model=ElectronIC,
        prior=lnprior,
        nwalkers=32,
        nburn=100,
        nrun=20,
        threads=4,
        prefit=True,
    )

    ## Save run results to HDF5 file (can be read later with naima.read_run)
    naima.save_run("RXJ1713_IC_run.hdf5", sampler)

    ## Diagnostic plots with labels for the metadata blobs
    naima.save_diagnostic_plots(
        "RXJ1713_IC",
        sampler,
        sed=True,
        last_step=False,
        blob_labels=[
            "Spectrum",
            "Electron energy distribution",
            "$W_e (E_e>1\, \mathrm{TeV})$",
        ],
    )
    naima.save_results_table("RXJ1713_IC", sampler)
# Out:
# INFO: Finding Maximum Likelihood parameters through Nelder-Mead fitting... [naima.core]
# INFO:    Initial parameters: [1.87859955e+32 3.00000000e+00 1.47712125e+00] [naima.core]
# INFO:    Initial lnprob(p0): -175.747 [naima.core]
# INFO:    New ML parameters : [1.38844563e+32 2.57175369e+00 1.68211459e+00] [naima.core]
# INFO:    Maximum lnprob(p0): -18.019 [naima.core]
# Burning in the 32 walkers with 100 steps...
#
# Progress of the run: 0 percent (0 of 100 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.39e+32          2.57            1.68
#   Last ensemble std    :     8.7e+29         0.0159           0.01
#   Last ensemble lnprob :  avg: -18.387, max: -18.006
#
# Progress of the run: 5 percent (5 of 100 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.39e+32          2.57            1.68
#   Last ensemble std    :     2.7e+30         0.0351          0.0155
#   Last ensemble lnprob :  avg: -19.097, max: -18.039
#
# Progress of the run: 10 percent (10 of 100 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.38e+32          2.57            1.68
#   Last ensemble std    :    3.28e+30         0.0457          0.0263
#   Last ensemble lnprob :  avg: -19.090, max: -18.037
#
# Progress of the run: 15 percent (15 of 100 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.38e+32          2.56            1.68
#   Last ensemble std    :    4.46e+30         0.0522          0.0411
#   Last ensemble lnprob :  avg: -19.209, max: -18.035
#
# Progress of the run: 20 percent (20 of 100 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.39e+32          2.59            1.67
#   Last ensemble std    :    5.29e+30         0.0626          0.0468
#   Last ensemble lnprob :  avg: -19.454, max: -18.064
#
# Progress of the run: 25 percent (25 of 100 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.39e+32          2.58            1.67
#   Last ensemble std    :    5.32e+30          0.06           0.0492
#   Last ensemble lnprob :  avg: -19.549, max: -18.030
#
# Progress of the run: 30 percent (30 of 100 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.38e+32          2.56            1.68
#   Last ensemble std    :    6.16e+30         0.0595          0.0571
#   Last ensemble lnprob :  avg: -19.581, max: -18.100
#
# Progress of the run: 35 percent (35 of 100 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.39e+32          2.55            1.68
#   Last ensemble std    :    5.73e+30         0.0595          0.0553
#   Last ensemble lnprob :  avg: -19.135, max: -17.986
#
# Progress of the run: 40 percent (40 of 100 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.39e+32          2.55            1.67
#   Last ensemble std    :    5.67e+30         0.0759          0.0676
#   Last ensemble lnprob :  avg: -19.196, max: -18.038
#
# Progress of the run: 45 percent (45 of 100 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :     1.4e+32          2.56            1.66
#   Last ensemble std    :    7.63e+30         0.0926           0.093
#   Last ensemble lnprob :  avg: -19.176, max: -17.990
#
# Progress of the run: 50 percent (50 of 100 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.37e+32          2.58             1.7
#   Last ensemble std    :    8.31e+30         0.0993           0.104
#   Last ensemble lnprob :  avg: -19.639, max: -18.019
#
# Progress of the run: 55 percent (55 of 100 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.38e+32          2.58            1.71
#   Last ensemble std    :    8.57e+30         0.0972           0.101
#   Last ensemble lnprob :  avg: -19.499, max: -18.042
#
# Progress of the run: 60 percent (60 of 100 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.38e+32          2.57            1.68
#   Last ensemble std    :    7.97e+30         0.0947           0.092
#   Last ensemble lnprob :  avg: -19.252, max: -18.078
#
# Progress of the run: 65 percent (65 of 100 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.37e+32          2.57            1.69
#   Last ensemble std    :    8.09e+30          0.106          0.0946
#   Last ensemble lnprob :  avg: -19.130, max: -18.063
#
# Progress of the run: 70 percent (70 of 100 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.34e+32          2.59             1.7
#   Last ensemble std    :    9.96e+30          0.122           0.11
#   Last ensemble lnprob :  avg: -19.507, max: -18.105
#
# Progress of the run: 75 percent (75 of 100 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.36e+32          2.57             1.7
#   Last ensemble std    :    8.03e+30          0.101          0.0994
#   Last ensemble lnprob :  avg: -19.119, max: -18.171
#
# Progress of the run: 80 percent (80 of 100 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.37e+32          2.56            1.69
#   Last ensemble std    :     9.4e+30          0.104           0.114
#   Last ensemble lnprob :  avg: -19.331, max: -18.167
#
# Progress of the run: 85 percent (85 of 100 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.39e+32          2.55            1.67
#   Last ensemble std    :    9.88e+30          0.12            0.119
#   Last ensemble lnprob :  avg: -19.436, max: -18.044
#
# Progress of the run: 90 percent (90 of 100 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.39e+32          2.54            1.67
#   Last ensemble std    :    1.04e+31          0.112           0.119
#   Last ensemble lnprob :  avg: -19.615, max: -18.128
#
# Progress of the run: 95 percent (95 of 100 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.37e+32          2.56            1.68
#   Last ensemble std    :    1.02e+31          0.106           0.117
#   Last ensemble lnprob :  avg: -19.433, max: -18.009
#
# Walker burn in finished, running 20 steps...
#
# Progress of the run: 0 percent (0 of 20 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.37e+32          2.56            1.69
#   Last ensemble std    :    8.49e+30         0.0815          0.0859
#   Last ensemble lnprob :  avg: -19.241, max: -17.996
#
# Progress of the run: 5 percent (1 of 20 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.38e+32          2.56            1.68
#   Last ensemble std    :    9.37e+30          0.092          0.0936
#   Last ensemble lnprob :  avg: -19.417, max: -18.027
#
# Progress of the run: 10 percent (2 of 20 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.38e+32          2.56             1.7
#   Last ensemble std    :     9.6e+30          0.092          0.0977
#   Last ensemble lnprob :  avg: -19.302, max: -18.048
#
# Progress of the run: 15 percent (3 of 20 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.39e+32          2.54            1.67
#   Last ensemble std    :    1.03e+31          0.102           0.105
#   Last ensemble lnprob :  avg: -19.460, max: -18.075
# Progress of the run: 20 percent (4 of 20 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.38e+32          2.54            1.67
#   Last ensemble std    :      1e+31           0.103           0.104
#   Last ensemble lnprob :  avg: -19.397, max: -18.102
#
# Progress of the run: 25 percent (5 of 20 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.37e+32          2.55            1.69
#   Last ensemble std    :    1.05e+31          0.108           0.108
#   Last ensemble lnprob :  avg: -19.520, max: -18.102
#
# Progress of the run: 30 percent (6 of 20 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.36e+32          2.55            1.69
#   Last ensemble std    :    1.09e+31          0.108           0.113
#   Last ensemble lnprob :  avg: -19.603, max: -18.016
#
# Progress of the run: 35 percent (7 of 20 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.37e+32          2.55            1.69
#   Last ensemble std    :    1.19e+31          0.122           0.128
#   Last ensemble lnprob :  avg: -19.847, max: -18.029
#
# Progress of the run: 40 percent (8 of 20 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.37e+32          2.59            1.71
#   Last ensemble std    :    1.13e+31          0.131           0.127
#   Last ensemble lnprob :  avg: -19.947, max: -18.066
#
# Progress of the run: 45 percent (9 of 20 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.38e+32          2.59            1.72
#   Last ensemble std    :    1.09e+31          0.123           0.125
#   Last ensemble lnprob :  avg: -19.941, max: -18.066
#
# Progress of the run: 50 percent (10 of 20 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.36e+32          2.59            1.72
#   Last ensemble std    :    1.06e+31          0.118           0.12
#   Last ensemble lnprob :  avg: -19.755, max: -18.127
#
# Progress of the run: 55 percent (11 of 20 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.36e+32          2.58            1.71
#   Last ensemble std    :    1.06e+31          0.12            0.123
#   Last ensemble lnprob :  avg: -19.799, max: -18.136
#
# Progress of the run: 60 percent (12 of 20 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.36e+32           2.6            1.72
#   Last ensemble std    :     1.1e+31          0.121           0.125
#   Last ensemble lnprob :  avg: -19.834, max: -18.253
#
# Progress of the run: 65 percent (13 of 20 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.36e+32          2.59            1.72
#   Last ensemble std    :     1.1e+31          0.12            0.12
#   Last ensemble lnprob :  avg: -19.811, max: -18.212
#
# Progress of the run: 70 percent (14 of 20 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.36e+32          2.59            1.72
#   Last ensemble std    :    1.04e+31          0.116           0.116
#   Last ensemble lnprob :  avg: -19.716, max: -18.157
#
# Progress of the run: 75 percent (15 of 20 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.35e+32           2.6            1.73
#   Last ensemble std    :    1.05e+31          0.108           0.113
#   Last ensemble lnprob :  avg: -19.623, max: -18.111
#
# Progress of the run: 80 percent (16 of 20 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.35e+32          2.58            1.72
#   Last ensemble std    :    1.05e+31          0.11            0.117
#   Last ensemble lnprob :  avg: -19.540, max: -18.026
#
# Progress of the run: 85 percent (17 of 20 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.35e+32          2.59            1.72
#   Last ensemble std    :    1.06e+31          0.108           0.118
#   Last ensemble lnprob :  avg: -19.549, max: -18.019
#
# Progress of the run: 90 percent (18 of 20 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.36e+32          2.59            1.71
#   Last ensemble std    :      9e+30          0.0934           0.103
#   Last ensemble lnprob :  avg: -19.262, max: -17.987
#
# Progress of the run: 95 percent (19 of 20 steps)
#                            -----norm------ -----index----- -log10(cutoff)-
#   Last ensemble median :    1.34e+32           2.6            1.72
#   Last ensemble std    :    9.55e+30         0.0966           0.11
#   Last ensemble lnprob :  avg: -19.319, max: -17.986
# WARNING: Not writing file because file exists and clobber is False [naima.analysis]
# INFO: Plotting chain of parameter norm... [naima.analysis]
# INFO: -----------------------norm-----------------------
#           norm = $(1.37^{+0.12}_{-0.08})\times10^{32}$ [naima.plot]
# INFO: Plotting chain of parameter index... [naima.analysis]
# INFO: ----------------------index-----------------------
#           index = $2.58 \pm 0.11$ [naima.plot]
# INFO: Plotting chain of parameter log10(cutoff)... [naima.analysis]
# INFO: ------------------log10(cutoff)-------------------
#           log10(cutoff) = $1.71 \pm 0.12$
#                  cutoff = $51 \pm 14$ [naima.plot]
# INFO: Plotting corner plot... [naima.analysis]
# INFO: Plotting Spectrum... [naima.analysis]
# /home/born-again/anaconda3/envs/gammapy-1.1/lib/python3.9/site-packages/naima/analysis.py:163: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   f.clf()
# INFO: Plotting Electron energy distribution... [naima.analysis]
# INFO: Plotting $W_e (E_e>1\, \mathrm{TeV})$... [naima.analysis]
# INFO: Saving results table in RXJ1713_IC_results.ecsv [naima.analysis]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 104
#      92 ## Diagnostic plots with labels for the metadata blobs
#      93 naima.save_diagnostic_plots(
#      94     "RXJ1713_IC",
#      95     sampler,
#    (...)
#     102     ],
#     103 )
# --> 104 naima.save_results_table("RXJ1713_IC", sampler)
#
# File ~/anaconda3/envs/gammapy-1.1/lib/python3.9/site-packages/naima/analysis.py:373, in save_results_table(outname, sampler, format, convert_log, last_step, include_blobs)
#     370     # Save it directly in meta for readability in ECSV
#     371     t.meta.update(metadata)
# --> 373 t.write("{0}_results.{1}".format(outname, file_extension), format=format)
#     375 return t
#
# File ~/anaconda3/envs/gammapy-1.1/lib/python3.9/site-packages/astropy/table/connect.py:130, in TableWrite.__call__(self, serialize_method, *args, **kwargs)
#     128 instance = self._instance
#     129 with serialize_method_as(instance, serialize_method):
# --> 130     self.registry.write(instance, *args, **kwargs)
#
# File ~/anaconda3/envs/gammapy-1.1/lib/python3.9/site-packages/astropy/io/registry/core.py:383, in UnifiedOutputRegistry.write(self, data, format, *args, **kwargs)
#     378     format = self._get_valid_format(
#     379         "write", data.__class__, path, fileobj, args, kwargs
#     380     )
#     382 writer = self.get_writer(format, data.__class__)
# --> 383 return writer(data, *args, **kwargs)
#
# File ~/anaconda3/envs/gammapy-1.1/lib/python3.9/site-packages/astropy/io/ascii/connect.py:28, in io_write(format, table, filename, **kwargs)
#      26     format = re.sub(r"^ascii\.", "", format)
#      27     kwargs["format"] = format
# ---> 28 return write(table, filename, **kwargs)
#
# File ~/anaconda3/envs/gammapy-1.1/lib/python3.9/site-packages/astropy/io/ascii/ui.py:941, in write(table, output, format, Writer, fast_writer, overwrite, **kwargs)
#     939     output = os.path.expanduser(output)
#     940     if not overwrite and os.path.lexists(output):
# --> 941         raise OSError(NOT_OVERWRITING_MSG.format(output))
#     943 if output is None:
#     944     output = sys.stdout
#
# OSError: File RXJ1713_IC_results.ecsv already exists. If you mean to replace it then use the argument "overwrite=True".
